# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torch.utils.data.sampler import BatchSampler

# %%
device = torch.device('cpu')

# %%
input_size = 784 # 28x28
hidden_size = 500 
num_classes = 10
num_epochs = 2
batch_size = 100
#test_batch_size = 10000
learning_rate = 0.001
spc=100
#SPC is for number of samples per class
t1=[]
t2=[]
t3=[]
i=0

# %%
# MNIST dataset 

train_dataset = torchvision.datasets.FashionMNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))]),  
                                           download=True)

test_dataset = torchvision.datasets.FashionMNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))]))


for i in range (10):
    t0=(train_dataset.targets==i).nonzero(as_tuple=False)
    t0 = t0.reshape(1, -1)
    t0 = t0.squeeze()
    t0=t0.tolist()
    np.random.shuffle(t0)
    t0=t0[0:spc]
    t1=t1+t0
    print ( "Current list size is" ,len(t1))
    print (spc," random samples for class" ,i, "is added to the list")

train_subset = torch.utils.data.Subset(train_dataset,t1)
#train_dataset0.targets = train_dataset.targets[t1]
#train_dataset0.data = train_dataset.data[t1]

t0=test_dataset.targets
t0 = t0.reshape(1, -1)
t0 = t0.squeeze()
t2=t0.tolist()
print ( "Test list size is" ,len(t2))
# Out:
# Current list size is 100
# 100  random samples for class 0 is added to the list
# Current list size is 200
# 100  random samples for class 1 is added to the list
# Current list size is 300
# 100  random samples for class 2 is added to the list
# Current list size is 400
# 100  random samples for class 3 is added to the list
# Current list size is 500
# 100  random samples for class 4 is added to the list
# Current list size is 600
# 100  random samples for class 5 is added to the list
# Current list size is 700
# 100  random samples for class 6 is added to the list
# Current list size is 800
# 100  random samples for class 7 is added to the list
# Current list size is 900
# 100  random samples for class 8 is added to the list
# Current list size is 1000
# 100  random samples for class 9 is added to the list
# Test list size is 10000

# %%
# Data loader


train_loader = DataLoader(dataset=train_subset, batch_size=batch_size, shuffle=False)


test_loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size ,shuffle=False)

print (len(test_loader))
print (len(test_dataset))
# Out:
# 100
# 10000

# %%
# Fully connected neural network with one hidden layer
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.input_size = input_size
        self.l1 = torch.nn.Linear(input_size, hidden_size) 
        self.relu = torch.nn.ReLU()
        self.l2 = torch.nn.Linear(hidden_size, num_classes)  
    
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        # no activation and no softmax at the end
        return out

# %%
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Train the model for all elements of the dataset
n_total_steps = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # origin shape: [100, 1, 28, 28]
        # resized: [100, 784]
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

# %%
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
t3=[]
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        tpredict=predicted.tolist()
        t3=t3+tpredict
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()
        print("Current total samples are",n_samples,)
        print("of which ",n_correct,"samples are correct")

        
print(len(t3))
       
acc = 100.0 * n_correct / n_samples
print(f'Accuracy of the network on the given test images: {acc} %')
# Out:
# Current total samples are 100
# of which  48 samples are correct
# Current total samples are 200
# of which  111 samples are correct
# Current total samples are 300
# of which  160 samples are correct
# Current total samples are 400
# of which  217 samples are correct
# Current total samples are 500
# of which  269 samples are correct
# Current total samples are 600
# of which  324 samples are correct
# Current total samples are 700
# of which  378 samples are correct
# Current total samples are 800
# of which  430 samples are correct
# Current total samples are 900
# of which  495 samples are correct
# Current total samples are 1000
# of which  545 samples are correct
# Current total samples are 1100
# of which  601 samples are correct
# Current total samples are 1200
# of which  651 samples are correct
# Current total samples are 1300
# of which  706 samples are correct
# Current total samples are 1400
# of which  760 samples are correct
# Current total samples are 1500
# of which  822 samples are correct
# Current total samples are 1600
# of which  880 samples are correct
# Current total samples are 1700
# of which  943 samples are correct
# Current total samples are 1800
# of which  992 samples are correct
# Current total samples are 1900
# of which  1050 samples are correct
# Current total samples are 2000
# of which  1098 samples are correct
# Current total samples are 2100
# of which  1153 samples are correct
# Current total samples are 2200
# of which  1212 samples are correct
# Current total samples are 2300
# of which  1274 samples are correct
# Current total samples are 2400
# of which  1334 samples are correct
# Current total samples are 2500
# of which  1394 samples are correct
# Current total samples are 2600
# of which  1449 samples are correct
# Current total samples are 2700
# of which  1495 samples are correct
# Current total samples are 2800
# of which  1553 samples are correct
# Current total samples are 2900
# of which  1603 samples are correct
# Current total samples are 3000
# of which  1650 samples are correct
# Current total samples are 3100
# of which  1711 samples are correct
# Current total samples are 3200
# of which  1758 samples are correct
# Current total samples are 3300
# of which  1807 samples are correct
# Current total samples are 3400
# of which  1858 samples are correct
# Current total samples are 3500
# of which  1910 samples are correct
# Current total samples are 3600
# of which  1966 samples are correct
# Current total samples are 3700
# of which  2020 samples are correct
# Current total samples are 3800
# of which  2067 samples are correct
# Current total samples are 3900
# of which  2111 samples are correct
# Current total samples are 4000
# of which  2166 samples are correct
# Current total samples are 4100
# of which  2215 samples are correct
# Current total samples are 4200
# of which  2266 samples are correct
# Current total samples are 4300
# of which  2310 samples are correct
# Current total samples are 4400
# of which  2374 samples are correct
# Current total samples are 4500
# of which  2442 samples are correct
# Current total samples are 4600
# of which  2504 samples are correct
# Current total samples are 4700
# of which  2560 samples are correct
# Current total samples are 4800
# of which  2620 samples are correct
# Current total samples are 4900
# of which  2684 samples are correct
# Current total samples are 5000
# of which  2733 samples are correct
# Current total samples are 5100
# of which  2786 samples are correct
# Current total samples are 5200
# of which  2837 samples are correct
# Current total samples are 5300
# of which  2890 samples are correct
# Current total samples are 5400
# of which  2953 samples are correct
# Current total samples are 5500
# of which  3016 samples are correct
# Current total samples are 5600
# of which  3065 samples are correct
# Current total samples are 5700
# of which  3123 samples are correct
# Current total samples are 5800
# of which  3181 samples are correct
# Current total samples are 5900
# of which  3237 samples are correct
# Current total samples are 6000
# of which  3296 samples are correct
# Current total samples are 6100
# of which  3351 samples are correct
# Current total samples are 6200
# of which  3412 samples are correct
# Current total samples are 6300
# of which  3465 samples are correct
# Current total samples are 6400
# of which  3521 samples are correct
# Current total samples are 6500
# of which  3576 samples are correct
# Current total samples are 6600
# of which  3627 samples are correct
# Current total samples are 6700
# of which  3670 samples are correct
# Current total samples are 6800
# of which  3732 samples are correct
# Current total samples are 6900
# of which  3783 samples are correct
# Current total samples are 7000
# of which  3845 samples are correct
# Current total samples are 7100
# of which  3902 samples are correct
# Current total samples are 7200
# of which  3962 samples are correct
# Current total samples are 7300
# of which  4016 samples are correct
# Current total samples are 7400
# of which  4079 samples are correct
# Current total samples are 7500
# of which  4142 samples are correct
# Current total samples are 7600
# of which  4204 samples are correct
# Current total samples are 7700
# of which  4257 samples are correct
# Current total samples are 7800
# of which  4315 samples are correct
# Current total samples are 7900
# of which  4368 samples are correct
# Current total samples are 8000
# of which  4426 samples are correct
# Current total samples are 8100
# of which  4479 samples are correct
# Current total samples are 8200
# of which  4532 samples are correct
# Current total samples are 8300
# of which  4587 samples are correct
# Current total samples are 8400
# of which  4653 samples are correct
# Current total samples are 8500
# of which  4714 samples are correct
# Current total samples are 8600
# of which  4761 samples are correct
# Current total samples are 8700
# of which  4813 samples are correct
# Current total samples are 8800
# of which  4867 samples are correct
# Current total samples are 8900
# of which  4930 samples are correct
# Current total samples are 9000
# of which  4988 samples are correct
# Current total samples are 9100
# of which  5041 samples are correct
# Current total samples are 9200
# of which  5089 samples are correct
# Current total samples are 9300
# of which  5138 samples are correct
# Current total samples are 9400
# of which  5199 samples are correct
# Current total samples are 9500
# of which  5252 samples are correct
# Current total samples are 9600
# of which  5308 samples are correct
# Current total samples are 9700
# of which  5363 samples are correct
# Current total samples are 9800
# of which  5428 samples are correct
# Current total samples are 9900
# of which  5488 samples are correct
# Current total samples are 10000
# of which  5542 samples are correct
# 10000
# Accuracy of the network on the given test images: 55.42 %

# %%
from sklearn.metrics import classification_report
#print(classification_report(labels, predicted, zero_division=1))
print(classification_report(t2, t3, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.17      0.29      1000
#            1       0.97      0.88      0.92      1000
#            2       0.55      0.31      0.40      1000
#            3       0.48      0.79      0.60      1000
#            4       0.39      0.72      0.51      1000
#            5       0.36      0.90      0.52      1000
#            6       1.00      0.00      0.00      1000
#            7       0.80      0.63      0.71      1000
#            8       0.97      0.29      0.45      1000
#            9       0.67      0.84      0.74      1000
#
#     accuracy                           0.55     10000
#    macro avg       0.71      0.55      0.51     10000
# weighted avg       0.71      0.55      0.51     10000

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(t2,t3))
# Out:
# [[175  16  20 476 142 165   0   1   3   2]
#  [  0 875   5  63  19  38   0   0   0   0]
#  [  3   1 313  19 408 248   0   0   0   8]
#  [  0   3   3 791  84 118   0   0   0   1]
#  [  0   3  92  71 725 103   0   0   2   4]
#  [  0   0   0   2   0 896   0  57   0  45]
#  [ 10   2 119 180 398 280   0   1   3   7]
#  [  0   0   0   0   0 285   0 632   0  83]
#  [  1   0  17  40  83 236   0  56 294 273]
#  [  0   0   0   4   5 105   0  45   0 841]]
