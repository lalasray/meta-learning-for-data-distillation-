# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torch.utils.data.sampler import BatchSampler

# %%
device = torch.device('cpu')

# %%
input_size = 784 # 28x28
hidden_size = 500 
num_classes = 10
num_epochs = 2
batch_size = 100
#test_batch_size = 10000
learning_rate = 0.001
spc=500
#SPC is for number of samples per class
t1=[]
t2=[]
t3=[]
i=0

# %%
# MNIST dataset 

train_dataset = torchvision.datasets.FashionMNIST(root='./data', 
                                           train=True, 
                                           transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))]),  
                                           download=True)

test_dataset = torchvision.datasets.FashionMNIST(root='./data', 
                                          train=False, 
                                          transform=transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))]))


for i in range (10):
    t0=(train_dataset.targets==i).nonzero(as_tuple=False)
    t0 = t0.reshape(1, -1)
    t0 = t0.squeeze()
    t0=t0.tolist()
    np.random.shuffle(t0)
    t0=t0[0:spc]
    t1=t1+t0
    print ( "Current list size is" ,len(t1))
    print (spc," random samples for class" ,i, "is added to the list")

train_subset = torch.utils.data.Subset(train_dataset,t1)
#train_dataset0.targets = train_dataset.targets[t1]
#train_dataset0.data = train_dataset.data[t1]

t0=test_dataset.targets
t0 = t0.reshape(1, -1)
t0 = t0.squeeze()
t2=t0.tolist()
print ( "Test list size is" ,len(t2))
# Out:
# Current list size is 500
# 500  random samples for class 0 is added to the list
# Current list size is 1000
# 500  random samples for class 1 is added to the list
# Current list size is 1500
# 500  random samples for class 2 is added to the list
# Current list size is 2000
# 500  random samples for class 3 is added to the list
# Current list size is 2500
# 500  random samples for class 4 is added to the list
# Current list size is 3000
# 500  random samples for class 5 is added to the list
# Current list size is 3500
# 500  random samples for class 6 is added to the list
# Current list size is 4000
# 500  random samples for class 7 is added to the list
# Current list size is 4500
# 500  random samples for class 8 is added to the list
# Current list size is 5000
# 500  random samples for class 9 is added to the list
# Test list size is 10000

# %%
# Data loader


train_loader = DataLoader(dataset=train_subset, batch_size=batch_size, shuffle=False)


test_loader = torch.utils.data.DataLoader(dataset=test_dataset,batch_size=batch_size ,shuffle=False)

print (len(test_loader))
print (len(test_dataset))
# Out:
# 100
# 10000

# %%
# Fully connected neural network with one hidden layer
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.input_size = input_size
        self.l1 = torch.nn.Linear(input_size, hidden_size) 
        self.relu = torch.nn.ReLU()
        self.l2 = torch.nn.Linear(hidden_size, num_classes)  
    
    def forward(self, x):
        out = self.l1(x)
        out = self.relu(out)
        out = self.l2(out)
        # no activation and no softmax at the end
        return out

# %%
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Train the model for all elements of the dataset
n_total_steps = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # origin shape: [100, 1, 28, 28]
        # resized: [100, 784]
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')

# %%
# Test the model
# In test phase, we don't need to compute gradients (for memory efficiency)
t3=[]
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        tpredict=predicted.tolist()
        t3=t3+tpredict
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()
        print("Current total samples are",n_samples,)
        print("of which ",n_correct,"samples are correct")

        
print(len(t3))
       
acc = 100.0 * n_correct / n_samples
print(f'Accuracy of the network on the given test images: {acc} %')
# Out:
# Current total samples are 100
# of which  33 samples are correct
# Current total samples are 200
# of which  63 samples are correct
# Current total samples are 300
# of which  98 samples are correct
# Current total samples are 400
# of which  136 samples are correct
# Current total samples are 500
# of which  166 samples are correct
# Current total samples are 600
# of which  205 samples are correct
# Current total samples are 700
# of which  239 samples are correct
# Current total samples are 800
# of which  278 samples are correct
# Current total samples are 900
# of which  310 samples are correct
# Current total samples are 1000
# of which  344 samples are correct
# Current total samples are 1100
# of which  373 samples are correct
# Current total samples are 1200
# of which  410 samples are correct
# Current total samples are 1300
# of which  426 samples are correct
# Current total samples are 1400
# of which  461 samples are correct
# Current total samples are 1500
# of which  492 samples are correct
# Current total samples are 1600
# of which  522 samples are correct
# Current total samples are 1700
# of which  560 samples are correct
# Current total samples are 1800
# of which  602 samples are correct
# Current total samples are 1900
# of which  636 samples are correct
# Current total samples are 2000
# of which  665 samples are correct
# Current total samples are 2100
# of which  700 samples are correct
# Current total samples are 2200
# of which  733 samples are correct
# Current total samples are 2300
# of which  761 samples are correct
# Current total samples are 2400
# of which  795 samples are correct
# Current total samples are 2500
# of which  827 samples are correct
# Current total samples are 2600
# of which  864 samples are correct
# Current total samples are 2700
# of which  898 samples are correct
# Current total samples are 2800
# of which  936 samples are correct
# Current total samples are 2900
# of which  964 samples are correct
# Current total samples are 3000
# of which  993 samples are correct
# Current total samples are 3100
# of which  1031 samples are correct
# Current total samples are 3200
# of which  1066 samples are correct
# Current total samples are 3300
# of which  1096 samples are correct
# Current total samples are 3400
# of which  1136 samples are correct
# Current total samples are 3500
# of which  1165 samples are correct
# Current total samples are 3600
# of which  1202 samples are correct
# Current total samples are 3700
# of which  1243 samples are correct
# Current total samples are 3800
# of which  1285 samples are correct
# Current total samples are 3900
# of which  1317 samples are correct
# Current total samples are 4000
# of which  1350 samples are correct
# Current total samples are 4100
# of which  1392 samples are correct
# Current total samples are 4200
# of which  1419 samples are correct
# Current total samples are 4300
# of which  1452 samples are correct
# Current total samples are 4400
# of which  1486 samples are correct
# Current total samples are 4500
# of which  1518 samples are correct
# Current total samples are 4600
# of which  1559 samples are correct
# Current total samples are 4700
# of which  1586 samples are correct
# Current total samples are 4800
# of which  1617 samples are correct
# Current total samples are 4900
# of which  1655 samples are correct
# Current total samples are 5000
# of which  1690 samples are correct
# Current total samples are 5100
# of which  1716 samples are correct
# Current total samples are 5200
# of which  1751 samples are correct
# Current total samples are 5300
# of which  1783 samples are correct
# Current total samples are 5400
# of which  1830 samples are correct
# Current total samples are 5500
# of which  1866 samples are correct
# Current total samples are 5600
# of which  1893 samples are correct
# Current total samples are 5700
# of which  1922 samples are correct
# Current total samples are 5800
# of which  1956 samples are correct
# Current total samples are 5900
# of which  1994 samples are correct
# Current total samples are 6000
# of which  2028 samples are correct
# Current total samples are 6100
# of which  2055 samples are correct
# Current total samples are 6200
# of which  2085 samples are correct
# Current total samples are 6300
# of which  2109 samples are correct
# Current total samples are 6400
# of which  2143 samples are correct
# Current total samples are 6500
# of which  2178 samples are correct
# Current total samples are 6600
# of which  2208 samples are correct
# Current total samples are 6700
# of which  2238 samples are correct
# Current total samples are 6800
# of which  2273 samples are correct
# Current total samples are 6900
# of which  2306 samples are correct
# Current total samples are 7000
# of which  2337 samples are correct
# Current total samples are 7100
# of which  2369 samples are correct
# Current total samples are 7200
# of which  2399 samples are correct
# Current total samples are 7300
# of which  2429 samples are correct
# Current total samples are 7400
# of which  2465 samples are correct
# Current total samples are 7500
# of which  2496 samples are correct
# Current total samples are 7600
# of which  2533 samples are correct
# Current total samples are 7700
# of which  2564 samples are correct
# Current total samples are 7800
# of which  2597 samples are correct
# Current total samples are 7900
# of which  2637 samples are correct
# Current total samples are 8000
# of which  2667 samples are correct
# Current total samples are 8100
# of which  2695 samples are correct
# Current total samples are 8200
# of which  2729 samples are correct
# Current total samples are 8300
# of which  2760 samples are correct
# Current total samples are 8400
# of which  2797 samples are correct
# Current total samples are 8500
# of which  2839 samples are correct
# Current total samples are 8600
# of which  2873 samples are correct
# Current total samples are 8700
# of which  2907 samples are correct
# Current total samples are 8800
# of which  2947 samples are correct
# Current total samples are 8900
# of which  2985 samples are correct
# Current total samples are 9000
# of which  3021 samples are correct
# Current total samples are 9100
# of which  3056 samples are correct
# Current total samples are 9200
# of which  3084 samples are correct
# Current total samples are 9300
# of which  3122 samples are correct
# Current total samples are 9400
# of which  3158 samples are correct
# Current total samples are 9500
# of which  3191 samples are correct
# Current total samples are 9600
# of which  3229 samples are correct
# Current total samples are 9700
# of which  3266 samples are correct
# Current total samples are 9800
# of which  3299 samples are correct
# Current total samples are 9900
# of which  3337 samples are correct
# Current total samples are 10000
# of which  3371 samples are correct
# 10000
# Accuracy of the network on the given test images: 33.71 %

# %%
from sklearn.metrics import classification_report
#print(classification_report(labels, predicted, zero_division=1))
print(classification_report(t2, t3, zero_division=1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.00      0.00      1000
#            1       1.00      0.00      0.00      1000
#            2       0.21      0.01      0.01      1000
#            3       1.00      0.00      0.00      1000
#            4       0.40      0.54      0.46      1000
#            5       1.00      0.00      0.00      1000
#            6       0.13      0.45      0.20      1000
#            7       0.31      0.97      0.47      1000
#            8       0.62      0.86      0.72      1000
#            9       0.98      0.55      0.70      1000
#
#     accuracy                           0.34     10000
#    macro avg       0.66      0.34      0.26     10000
# weighted avg       0.66      0.34      0.26     10000

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(t2,t3))
# Out:
# [[  0   0   1   0  15   0 793 151  40   0]
#  [  0   0   0   0  38   0 888  68   6   0]
#  [  0   0   6   0 485   0 234 109 166   0]
#  [  0   0   0   0  20   0 788 155  37   0]
#  [  0   0   3   0 535   0 341  59  62   0]
#  [  0   0   0   0   0   0   1 973  20   6]
#  [  0   0   6   0 220   0 450 185 139   0]
#  [  0   0   0   0   0   0   0 973  20   7]
#  [  0   0  12   0  17   0  15  99 857   0]
#  [  0   0   0   0   1   0  20 392  37 550]]
